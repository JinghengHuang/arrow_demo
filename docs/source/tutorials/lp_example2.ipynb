# %% [markdown]
# # LP Example: FBA analysis for ecoli model
#
# In this example, we solve a **linear programming (LP)** problem to optimize the flux balance analysis (FBA) for the E. coli metabolic model.
